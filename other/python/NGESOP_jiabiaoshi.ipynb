# %%
import cn_class_4alogin
import requests
import sys
reload(sys)
sys.setdefaultencoding( "utf-8" )

r=requests.session()
header={'User-Agent':'Mozilla/5.0 (X11; Linux x86_64; rv:44.0) Gecko/20100101 Firefox/44.0','Accept-Language':'en-US,en;q=0.5'}

json2=cn_class_4alogin.cn_4ALogin(r,'qWer1@34','41608446240A6782F2A0F031426EDC066CF24674F3F0586AF1E3983438A09296B93FF648FA4937967A053D1D504E42BA6069ED5C9B03B580')
# cn_class_4alogin.cn_BossLogin(r,json2)
cn_class_4alogin.cn_ESOPLogin(r,json2)
# Out:
# 验证码:181469

# %%
import random
from bs4 import BeautifulSoup
import time
import datetime

cn_GROUPID='82000020636110'
cn_subsid='82000020636110'
cn_group='2002519707'
def cn_cookies(cookies):
        cookies = dict()
        for i in r.cookies.get_dict('esop.boss.gmcc.net'):
            cookies[i]=r.cookies.get(i,'','esop.boss.gmcc.net')
        cookies['com.huawei.boss.CURRENT_MENUID']='ESOP_GRP_100010061038'
        cookies['com.huawei.boss.CURRENT_TAB']='ESOP_GRP_100010061038'
        return cookies

def cn_xinkuayue(r,cn_SERVNUMBER):
    # 生成菜单

    s=r.get('http://esop.boss.gmcc.net/esop/dashboard/menu/ngcrm/toCommonMiddlePage.action?ngcrmMenuInfoBean.menuId=ESOP_GRP_100010061038&logId=customer')



    # 查询集团
    url='http://esop.boss.gmcc.net/ngcustcare_fs/group/commonquery/queryCustomerInfo.action?recType=GroupMemberMgrAdd'
    params={'groupOrMemeber':'group','groupId':cn_group,'grpMem.qryType':'SERVNUMBER','grpMem.inputVal':'','grpMem.startTime':'','grpMem.startTime_format':'yyyy-MM-dd HH:mm:ss','grpMem.endTime':'','grpMem.endTime_format':'yyyy-MM-dd HH:mm:ss'}
    r.post(url,data=params)
    
    url='http://esop.boss.gmcc.net/ngcustcare_fs/group/groupMemberMg/subsListInit.action'
    params={'groupOrMemeber':'group','groupId':cn_group,'grpMem.qryType':'ALL','grpMem.inputVal':'','grpMem.startTime':'','grpMem.startTime_format':'yyyy-MM-dd HH:mm:ss','grpMem.endTime':'','grpMem.endTime_format':'yyyy-MM-dd HH:mm:ss'}
    r.post(url,data=params)
    
    url='http://esop.boss.gmcc.net/ngcustcare_fs/group/commonquery/querySubscriberInfo.action?subsId='+cn_subsid
    r.post(url,data=params)


    # 获取currSubsId
    cn_random='0.'+str(random.randint(1000000000000000,9999999999999999))+str(random.randint(1,9))
    url='http://esop.boss.gmcc.net/ngcustcare_fs/group/groupMemberMg/preAdd.action?ngcrm_rnd='+cn_random+'&ngcrm_reserved1=1&subsId='+cn_subsid+'&servNumber='+cn_SERVNUMBER+'&memeberType=0&productId=I00010300001'
    s=r.get(url)
    soup=BeautifulSoup(s.text,'lxml')
    # 成员管理界面
    url='http://esop.boss.gmcc.net'+soup.find(attrs={"name":"productFrame"}).attrs['src']
    s=r.get(url)
    soup=BeautifulSoup(s.text,'lxml')
    # XXX_effectType
    cn_effectType_NUM=soup.find(attrs={'title':'ID:AppendAttr.I00010300001'}).attrs['objectid']
    print 'cn_effectType_NUM',cn_effectType_NUM

    
    cn_random_data='Mon Dec 12 '+datetime.datetime.now().strftime("%H:%M:%S")+' UTC+0800 2016'
    params={'SEARCHPRODID':'','SEARCHPRODNAME':'','SEARCHPRECISION':'0','SEARCHCATALOGID':'SMS MMSpackage3','appendConditonValue':'','searchShortId':'','accurateSearch':'false','random':cn_random_data}
    s=r.post('http://esop.boss.gmcc.net/ngcustcare_fs/product/productTreeAction!searchProducts.action',data=params)
    soup=BeautifulSoup(s.text,'lxml')
#     cn_objectID_1=soup.find(attrs={'title':'ID:I00010100003'}).attrs['objectid']
    cn_objectID_2=soup.find(attrs={'title':'ID:I00010100027'}).attrs['objectid']

    cn_random_data='Mon Dec 12 '+datetime.datetime.now().strftime("%H:%M:%S")+' UTC+0800 2016'
    params={'cilckfrom':'getPackProdList','sign':'catalogProductTable','objectID':cn_objectID_2,'random':cn_random_data}
    s=r.post('http://esop.boss.gmcc.net/ngcustcare_fs/product/productTreeAction!getPackProdList.action',data=params)
#     soup0=BeautifulSoup(s.text,'lxml')
    soup0=BeautifulSoup(s.text,'lxml')

#     # 第一个标识(I00010100008,"短信基础服务产品(标准)" )
#     cn_objectID=soup0.find(attrs={'title':'ID:I00010100008'}).attrs['objectid']
#     cn_random='0.0'+str(random.randint(100000000000000,999999999999999))+str(random.randint(1,9))
#     url='http://esop.boss.gmcc.net/ngcustcare_fs/product/productTreeAction!addToCar.action?catalogName=%E7%9F%AD%E4%BF%A1%E5%BD%A9%E4%BF%A1%E5%A5%97%E9%A4%90(2)&catalogId=SMS%20MMSpackage3&appendCatalogSelect=SMS%20MMSpackage3&searchId=&searchName=&append_ConditonValue=&'+cn_effectType_NUM+'_effectType=0&entityID=I00010100008&sign=catalogProductTable&parentID=I00010100003&objectID='+cn_objectID+'&parentObjID=&isHappyOnlineFlag=&random='+cn_random
#     s=r.get(url)
#     soup=BeautifulSoup(s.text,'lxml')
#     cn_objectID=soup.find(attrs={'title':'ID:I00010100008'}).attrs['objectid']
#     # 用于下一个标识
#     cn_objectID_N=soup.find(attrs={'title':'ID:I00010100003'}).attrs['objectid']

#     # #第一个标识-附
#     params={'objectID':cn_objectID,'SERVNUMBER':cn_SERVNUMBER,'cataType':'2','productID':'I00010100008','baseProdID':'I00010300001','productName':u'短信基础服务产品(标准)','contextPath':'/ngcustcare_fs','recType':'GroupMemberMgrAdd','productEditStatus':'0','OPERATORTYPE':'1','serv_29613_200':'0','serv_75000000096006_200':'1064899192010','serv_75000000096007_200':'01','t':''}
#     cn_random='0.'+str(random.randint(100000000000000,999999999999999))+str(random.randint(1,9))
#     r.post('http://esop.boss.gmcc.net/ngcustcare_fs/product/appendAttrAction!saveAttr.action?resoureFileFlag=0&isProv=&provValueId=&random='+cn_random,data=params)


#     # 第二个标识(I00010100045,"短信1元套餐(标准)"  )
#     cn_objectID=soup0.find(attrs={'title':'ID:I00010100045'}).attrs['objectid']
#     cn_random='0.'+str(random.randint(100000000000000,999999999999999))+str(random.randint(1,9))
#     s=r.get('http://esop.boss.gmcc.net/ngcustcare_fs/product/productTreeAction!addToCar.action?catalogName=%E7%9F%AD%E4%BF%A1%E5%BD%A9%E4%BF%A1%E5%A5%97%E9%A4%90(2)&catalogId=SMS%20MMSpackage3&appendCatalogSelect=SMS%20MMSpackage3&searchId=&searchName=&append_ConditonValue=&'+cn_effectType_NUM+'_effectType=0&'+cn_objectID_N+'_effectType=0&entityID=I00010100045&sign=catalogProductTable&parentID=I00010100003&objectID='+cn_objectID+'&parentObjID='+cn_objectID_N+'&isHappyOnlineFlag=&random='+cn_random)
#     soup=BeautifulSoup(s.text,'lxml')

    # 第三个标识(I00010100061,"GPRS中小流量新3元套餐（原子产品）"   )
#     cn_objectID_N2=soup.find(attrs={'title':'ID:I00010100045'}).attrs['objectid']
#     cn_random='0.'+str(random.randint(100000000000000,999999999999999))+str(random.randint(1,9))
#     cn_random_data='Thu May 12 '+datetime.datetime.now().strftime("%H:%M:%S")+' UTC+0800 2016'
#     params={'cilckfrom':'getPackProdList','sign':'catalogProductTable','objectID':cn_objectID_2,'random':cn_random_data}
#     s=r.post('http://esop.boss.gmcc.net/ngcustcare_fs/product/productTreeAction!getPackProdList.action',data=params)
#     soup0=BeautifulSoup(s.text,'lxml')
    cn_objectID=soup0.find(attrs={'title':'ID:I00010100061'}).attrs['objectid']
    s=r.get('http://esop.boss.gmcc.net/ngcustcare_fs/product/productTreeAction!addToCar.action?catalogName=%E7%9F%AD%E4%BF%A1%E5%BD%A9%E4%BF%A1%E5%A5%97%E9%A4%90(2)&catalogId=SMS%20MMSpackage3&appendCatalogSelect=SMS%20MMSpackage3&searchId=&searchName=&append_ConditonValue=&'+cn_effectType_NUM+'_effectType=0&entityID=I00010100061&sign=catalogProductTable&parentID=I00010100027&objectID='+cn_objectID+'&parentObjID=&isHappyOnlineFlag=&random='+cn_random)
    soup=BeautifulSoup(s.text,'lxml')
    
    cn_objectID_N=soup.find(attrs={'title':'ID:I00010100027'}).attrs['objectid']
    cn_objectID_N2=soup.find(attrs={'title':'ID:I00010100061'}).attrs['objectid']
    print 'cn_objectID_N',cn_objectID_N
    print 'cn_objectID_N2',cn_objectID_N2
    
    #第三个标识-附
    cn_objectID=soup.find(attrs={'title':'ID:I00010100061'}).attrs['objectid']
    cn_random='0.'+str(random.randint(100000000000000,999999999999999))+str(random.randint(1,9))
    params={'objectID':cn_objectID,'SERVNUMBER':cn_SERVNUMBER,'cataType':'2','productID':'I00010100061','baseProdID':'I00010300001','productName':u'GPRS中小流量新3元套餐（原子产品）','contextPath':'/ngcustcare_fs','recType':'GroupMemberMgrAdd','productEditStatus':'0','OPERATORTYPE':'1','serv_S00010100061_discount':'100','t':''}
    s=r.post('http://esop.boss.gmcc.net/ngcustcare_fs/product/appendAttrAction!saveAttr.action?resoureFileFlag=0&isProv=&provValueId=&random='+cn_random,data=params)


    # 第四个标识
    cn_random='0.'+str(random.randint(100000000000000,999999999999999))+str(random.randint(1,9))
    cn_objectID=soup0.find(attrs={'title':'ID:I00010100085'}).attrs['objectid']
    cn_objectID_P=soup.find(attrs={'title':'ID:I00010100027'}).attrs['objectid']
    s=r.get('http://esop.boss.gmcc.net/ngcustcare_fs/product/productTreeAction!addToCar.action?catalogName=%E7%9F%AD%E4%BF%A1%E5%BD%A9%E4%BF%A1%E5%A5%97%E9%A4%90(2)&catalogId=SMS%20MMSpackage3&appendCatalogSelect=SMS%20MMSpackage3&searchId=&searchName=&append_ConditonValue=&'+cn_effectType_NUM+'_effectType=0&'+cn_objectID_N+'_effectType=0&'+cn_objectID_N2+'_effectType=0&entityID=I00010100085&sign=catalogProductTable&parentID=I00010100027&objectID='+cn_objectID+'&parentObjID='+cn_objectID_P+'&isHappyOnlineFlag=&random='+cn_random)
    # 添加标识-附
    # GPRS通信服务产品
    cn_random='0.'+str(random.randint(100000000000000,999999999999999))+str(random.randint(1,9))
    soup=BeautifulSoup(s.text,'lxml')
    cn_objectID=soup.find(attrs={'title':'ID:I00010100085'}).attrs['objectid']
    params={'objectID':cn_objectID,'SERVNUMBER':cn_SERVNUMBER,'cataType':'2','productID':'I00010100085','baseProdID':'I00010300001','productName':u'数据通信服务产品','contextPath':'/ngcustcare_fs','recType':'GroupMemberMgrAdd','productEditStatus':'0','OPERATORTYPE':'1','serv_S00010100085_APNNAME':'CMMTM','serv_S00010100085_M2M_StopOrResume':'0','t':''}
    url='http://esop.boss.gmcc.net/ngcustcare_fs/product/appendAttrAction!saveAttr.action?resoureFileFlag=0&isProv=&provValueId=&random='+cn_random
    r.post(url,data=params)

    # # 关系检查
    cn_random='0.'+str(random.randint(100000000000000,999999999999999))+str(random.randint(1,9))
    url='http://esop.boss.gmcc.net/ngcustcare_fs/product/productInstallAction!prodRecCheck.action?catalogName=%E7%9F%AD%E4%BF%A1%E5%BD%A9%E4%BF%A1%E5%A5%97%E9%A4%90(2)&catalogId=SMS%20MMSpackage3&appendCatalogSelect=SMS%20MMSpackage3&searchId=&searchName=&append_ConditonValue=&'+cn_effectType_NUM+'_effectType=0&'+cn_objectID_N+'_effectType=0&'+cn_objectID_N2+'_effectType=0&random='+cn_random
    s=r.get(url)
    cn_random='0.'+str(random.randint(100000000000000,999999999999999))+str(random.randint(1,9))
    url='http://esop.boss.gmcc.net/ngcustcare_fs/product/productInstallAction!showProdEffectTime.action?type=install&random='+cn_random
    s=r.get(url)
    # print s.text

    # 关系检查完点下一步
    url='http://esop.boss.gmcc.net/ngcustcare_fs/group/groupMemberMg/add.action?subsId=82000020636110&memOid=&memeberType=0&servNumber='+cn_SERVNUMBER+'&grpMem.isSendSecondMsg=&grpMem.isSendSucceedMsg=&grpMem.channelFirst=ExpandChaType1&grpMem.channelSecond=&grpMem.channelThird=&RECTYPE=GROUPREC&timeTag='+str(time.time()).replace('.','1')
    s=r.get(url)
    soup=BeautifulSoup(s.text,'lxml')
    # print soup
    cn_ESOP_GRP_100010061038_fee=soup.find(attrs={'name':'_fee/calculate'}).attrs['value']
#     print cn_ESOP_GRP_100010061038_fee

    s=r.get('http://esop.boss.gmcc.net/ngcustcare_fs/common/managerMan/managerManQuery.action?noHeader=1&random='+str(time.time()).replace('.','1'))
    params={'selRecType':'','selCusCertType':'','recCustInfoName':'%E6%A2%81*%E7%BE%A4','recCustInfoCertificateType':'IdCard','reccustInfoCertificateNum':'********','reccustInfoAddress':''}
    # cn_cookies1=cn_cookies(s.cookies)
049088;1064856049089;1064856049090;1064856049091;1064856049092;1064856049093;1064856049094;1064856049095;1064856049096;1064856049097;1064856049098;1064856049099;1064856049100;1064856049101;1064856049102;1064856049103;1064856049104;1064856049105;1064856049106;1064856049107;1064856049108;1064856049109;1064856049110;1064856049111;1064856049112;1064856049113;1064856049114;1064856049115;1064856049116;1064856049117;1064856049118;1064856049119;1064856049120;1064856049121;1064856049122;1064856049123;1064856049124;1064856049125;1064856049126;1064856049127;1064856049128;1064856049129;1064856049130;1064856049131;1064856049132;1064856049133;1064856049134;1064856049135;1064856049136;1064856049137;1064856049138;1064856049139;1064856049140;1064856049141;1064856049142;1064856049143;1064856049144;1064856049145;1064856049146;1064856049147;1064856049148;1064856049149;1064856049150;1064856049151;1064856049152;1064856049153;1064856049154;1064856049155;1064856049156;1064856049157;1064856049158;1064856049159;1064856049160;1064856049161;1064856049162;1064856049163;1064856049164;1064856049165;1064856049166;1064856049167;1064856049168;1064856049169;1064856049170;1064856049171;1064856049172;1064856049173;1064856049174'
ff=ff.split(';')

# cn_chengyuancaidan_1(r)

for i in ff:
    result=cn_xinkuayue(r,i)
    cn_file=file('abc','a')
    cn_file.write("\n"+str(i)+','+result)
    cn_file.close()
    print i,result
  
       
    time.sleep(2)
cn_file=file('abc','a')
cn_file.write("\n=========end===========")  
cn_file.close()

# %%
#下面是只加成员,不加标识
import random
from bs4 import BeautifulSoup
import time
import datetime
cn_groupId='2000129351'
cn_SERVNUMBER='1064818035815'
cn_subsId='82000020689589'
cn_GROUPID='82000020636110'

def cn_cookies(cookies):
        cookies = dict()
        for i in r.cookies.get_dict('esop.boss.gmcc.net'):
            cookies[i]=r.cookies.get(i,'','esop.boss.gmcc.net')
        cookies['com.huawei.boss.CURRENT_MENUID']='ESOP_GRP_100010061038'
        cookies['com.huawei.boss.CURRENT_TAB']='ESOP_GRP_100010061038'
        return cookies

def cn_chengyuancaidan_1(r):
    # 生成菜单

    s=r.get('http://esop.boss.gmcc.net/esop/dashboard/menu/ngcrm/toCommonMiddlePage.action?ngcrmMenuInfoBean.menuId=ESOP_GRP_100010061038&logId=customer')

    # 查询集团
    url='http://esop.boss.gmcc.net/ngcustcare_fs/group/commonquery/queryCustomerInfo.action?recType=GroupMemberMgrAdd'
    params={'groupOrMemeber':'group','groupId':cn_groupId,'grpMem.qryType':'ALL','grpMem.inputVal':'','grpMem.startTime':'','grpMem.startTime_format':'yyyy-MM-dd HH:mm:ss','grpMem.endTime':'','grpMem.endTime_format':'yyyy-MM-dd HH:mm:ss'}
    r.post(url,data=params)
    url='http://esop.boss.gmcc.net/ngcustcare_fs/group/groupMemberMg/subsListInit.action'
    r.post(url,data=params)
    url='http://esop.boss.gmcc.net/ngcustcare_fs/group/commonquery/querySubscriberInfo.action?subsId='+cn_subsId
    r.post(url,data=params)

def cn_chengyuancaidan_2(r,cn_SERVNUMBER):
    # 获取currSubsId
    cn_random='0.'+str(random.randint(100000000000000,999999999999999))+str(random.randint(1,9))
    url='http://esop.boss.gmcc.net/ngcustcare_fs/group/groupMemberMg/preAdd.action?ngcrm_rnd='+cn_random+'&ngcrm_reserved1=1&subsId='+cn_subsId+'&servNumber='+cn_SERVNUMBER+'&memeberType=0&productId=I00010300001'
    s=r.get(url)
    soup=BeautifulSoup(s.text,'lxml')
    # 成员管理界面
    url='http://esop.boss.gmcc.net'+soup.find(attrs={"name":"productFrame"}).attrs['src']
    s=r.get(url)
    soup=BeautifulSoup(s.text,'lxml')
#     print soup
    cn_objectID=soup.find(attrs={'entityname':u'机器卡集团成员产品'}).attrs['objectid']
#     print cn_objectID
    
     # # 关系检查
    cn_random='0.'+str(random.randint(100000000000000,999999999999999))+str(random.randint(1,9))
    url='http://esop.boss.gmcc.net/ngcustcare_fs/product/productInstallAction!prodRecCheck.action?catalogName=&catalogId=&appendCatalogSelect=ROOT_&searchId=&searchName=&'+cn_objectID+'_effectType=0&random='+cn_random
    s=r.get(url)
    cn_random='0.'+str(random.randint(100000000000000,999999999999999))+str(random.randint(1,9))
    url='http://esop.boss.gmcc.net/ngcustcare_fs/product/productInstallAction!showProdEffectTime.action?type=install&random='+cn_random
    s=r.get(url)
    # print s.text

    # 关系检查完点下一步
    url='http://esop.boss.gmcc.net/ngcustcare_fs/group/groupMemberMg/add.action?subsId='+cn_subsId+'&memOid=&memeberType=0&servNumber='+cn_SERVNUMBER+'&grpMem.isSendSecondMsg=&grpMem.isSendSucceedMsg=&grpMem.channelFirst=ExpandChaType1&grpMem.channelSecond=&grpMem.channelThird=&RECTYPE=GROUPREC&timeTag='+str(time.time()).replace('.','1')
    s=r.get(url)
    soup=BeautifulSoup(s.text,'lxml')
#     print soup
    cn_ESOP_GRP_100010061038_fee=soup.find(attrs={'name':'_fee/calculate'}).attrs['value']
#     print cn_ESOP_GRP_100010061038_fee

    s=r.get('http://esop.boss.gmcc.net/ngcustcare_fs/common/managerMan/managerManQuery.action?noHeader=1&random='+str(time.time()).replace('.','1'))
    params={'selRecType':'','selCusCertType':'','recCustInfoName':'%E6%A2%81*%E7%BE%A4','recCustInfoCertificateType':'IdCard','reccustInfoCertificateNum':'********','reccustInfoAddress':''}
    # cn_cookies1=cn_cookies(s.cookies)
    s=r.post('http://esop.boss.gmcc.net/ngcustcare_fs/custinfo/changeInfo/chkRecCustInfoChgCstInfo.action',data=params)

    # # 准备提交
    params={'PreBussOrderId':'','withdrawGoods':'','payTypeBean.cashAmt':'','payTypeBean.chequeAmt':'','payTypeBean.bankId':'','payTypeBean.bankName':'','payTypeBean.chequeNum':'','payTypeBean.cardAmt':'','payTypeBean.posNum':'','payTypeBean.confirmPosNum':'','payTypeBean.acctCash':'','payTypeBean.scoreCash':'','payTypeBean.score':'','payTypeBean.scoreTransRule':'1/1','payTypeBean.m':'0','payTypeBean.mTransRule':'1/1','payTypeBean.separateAmt':'','payTypeBean.separateBankId':'GH','payTypeBean.separateBankName':u'工行','payTypeBean.separateBankAcct':'','payTypeBean.separateBankUserName':'','payTypeBean.separatePosNum':'','payTypeBean.limitCash':'','payTypeBean.unl